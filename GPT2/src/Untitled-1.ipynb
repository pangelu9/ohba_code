# %%
import numpy as np 

path = "meg_data_tokenized_data1.npy"
data = np.load(path)     
#data = np.random.permutation(data)
print(data.shape)
squeezed_data = np.squeeze(data, axis=-1)
print(squeezed_data.shape)
np.save('meg_data_tokenized_data1.npy', squeezed_data)
# Out:
# (1280004, 1)
# (1280004,)

# %%
import numpy as np 

path = "generated_data_recursively.npy"
data = np.load(path)   
data = np.expand_dims(data, axis=-1)  
print(data.shape)
np.save('generated_data_recursively.npy', data)
# Out:
# (10100, 1)

# %%
import matplotlib.pyplot as plt

time_points = np.arange(len(data))
plt.plot(time_points, data)
